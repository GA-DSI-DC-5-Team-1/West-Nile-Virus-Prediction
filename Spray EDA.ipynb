# %% [markdown]
# # Spray Dataset EDA
# Andy Gonzalez
#
# ### Learning Objectives
# *After this lesson, you should be able to:*

# %%
#math
import pandas as pd
import numpy as np
#plots
import matplotlib.pyplot as plt
import seaborn as sns
#pip install geopy   <-- put in terminal
from geopy.geocoders import Nominatim

# %%
data = pd.read_csv('/Users/andresgonzalez/Desktop/GA/curriculum/West-Nile-Virus-Prediction/assets/spray.csv')

# %%
data.head()
# Out:
#          Date        Time   Latitude  Longitude
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858

# %%
def eda(dataframe):
    print "missing values \n", dataframe.isnull().sum()
    print "dataframe index \n", dataframe.index
    print "dataframe types \n", dataframe.dtypes
    print "dataframe shape \n", dataframe.shape
    print "dataframe describe \n", dataframe.describe()
    print "dataframe duplicates \n", dataframe.duplicated().sum() 
    for item in dataframe:
        print item
        print dataframe[item].nunique()

# %%
data['full_date'] = data.Date.str.cat(data.Time, sep=" ")
data['full_date'] = pd.to_datetime(data['full_date'])

data.head()
# Out:
#          Date        Time   Latitude  Longitude           full_date
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163 2011-08-29 18:56:58
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163 2011-08-29 18:57:08
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157 2011-08-29 18:57:18
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158 2011-08-29 18:57:28
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858 2011-08-29 18:57:38

# %%
data[data.duplicated()]
# Out:
#             Date        Time   Latitude  Longitude           full_date
# 485   2011-09-07  7:43:40 PM  41.983917 -87.793088 2011-09-07 19:43:40
# 490   2011-09-07  7:44:32 PM  41.986460 -87.794225 2011-09-07 19:44:32
# 491   2011-09-07  7:44:32 PM  41.986460 -87.794225 2011-09-07 19:44:32
# 492   2011-09-07  7:44:32 PM  41.986460 -87.794225 2011-09-07 19:44:32
# 493   2011-09-07  7:44:32 PM  41.986460 -87.794225 2011-09-07 19:44:32
# 494   2011-09-07  7:44:32 PM  41.986460 -87.794225 2011-09-07 19:44:32
# 495   2011-09-07  7:44:32 PM  41.986460 -87.794225 2011-09-07 19:44:32
# 496   2011-09-07  7:44:32 PM  41.986460 -87.794225 2011-09-07 19:44:32
# 497   2011-09-07  7:44:32 PM  41.986460 -87.794225 2011-09-07 19:44:32
# 498   2011-09-07  7:44:32 PM  41.986460 -87.794225 2011-09-07 19:44:32
# 499   2011-09-07  7:44:32 PM  41.986460 -87.794225 2011-09-07 19:44:32
# 500   2011-09-07  7:44:32 PM  41.986460 -87.794225 2011-09-07 19:44:32
# ...

# %%
data.drop_duplicates()
# Out:
#              Date        Time   Latitude  Longitude           full_date
# 0      2011-08-29  6:56:58 PM  42.391623 -88.089163 2011-08-29 18:56:58
# 1      2011-08-29  6:57:08 PM  42.391348 -88.089163 2011-08-29 18:57:08
# 2      2011-08-29  6:57:18 PM  42.391022 -88.089157 2011-08-29 18:57:18
# 3      2011-08-29  6:57:28 PM  42.390637 -88.089158 2011-08-29 18:57:28
# 4      2011-08-29  6:57:38 PM  42.390410 -88.088858 2011-08-29 18:57:38
# 5      2011-08-29  6:57:48 PM  42.390395 -88.088315 2011-08-29 18:57:48
# 6      2011-08-29  6:57:58 PM  42.390673 -88.088002 2011-08-29 18:57:58
# 7      2011-08-29  6:58:08 PM  42.391027 -88.088002 2011-08-29 18:58:08
# 8      2011-08-29  6:58:18 PM  42.391403 -88.088003 2011-08-29 18:58:18
# 9      2011-08-29  6:58:28 PM  42.391718 -88.087995 2011-08-29 18:58:28
# 10     2011-08-29  6:58:38 PM  42.392038 -88.087988 2011-08-29 18:58:38
# 11     2011-08-29  6:58:48 PM  42.392410 -88.088078 2011-08-29 18:58:48
# ...

# %%
eda(data)
# Out:
# missing values
# Date           0
# Time         584
# Latitude       0
# Longitude      0
# full_date    584
# dtype: int64
# dataframe index
# RangeIndex(start=0, stop=14835, step=1)
# dataframe types
# Date                 object
# Time                 object
# Latitude            float64
# Longitude           float64
# full_date    datetime64[ns]
# dtype: object
# dataframe shape
# (14835, 5)
# dataframe describe
#            Latitude     Longitude
# count  14835.000000  14835.000000
# mean      41.904828    -87.736690
# std        0.104381      0.067292
# min       41.713925    -88.096468
# 25%       41.785001    -87.794225
# 50%       41.940075    -87.727853
# 75%       41.980978    -87.694108
# max       42.395983    -87.586727
# dataframe duplicates
# 541
# Date
# 10
# Time
# 8583
# Latitude
# 12887
# Longitude
# 13007
# full_date
# 12325

# %%
geolocator = Nominatim()
loc = geolocator.reverse("42.391623, -88.089163")
print loc.address
# Out:
# Ridgewood Lane, Lake Villa, Lake County, Illinois, 60073, United States of America

# %%
# data['address'] = np.nan
data.head()
# Out:
#          Date        Time   Latitude  Longitude           full_date
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163 2011-08-29 18:56:58
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163 2011-08-29 18:57:08
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157 2011-08-29 18:57:18
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158 2011-08-29 18:57:28
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858 2011-08-29 18:57:38

# %%
data.Date.value_counts()
# Out:
# 2013-08-15    2668
# 2013-08-29    2302
# 2013-07-17    2202
# 2011-09-07    2114
# 2013-07-25    1607
# 2013-08-22    1587
# 2013-08-08    1195
# 2013-09-05     924
# 2013-08-16     141
# 2011-08-29      95
# Name: Date, dtype: int64

# %%
pd.unique(data.Date)
# Out:
# array(['2011-08-29', '2011-09-07', '2013-07-17', '2013-07-25',
#        '2013-08-08', '2013-08-15', '2013-08-16', '2013-08-22',
#        '2013-08-29', '2013-09-05'], dtype=object)

# %%
print min(data.Time), max(data.Time)

print data.Time.value_counts()
# Out:
# nan 9:59:58 PM
# 7:44:32 PM     541
# 8:59:06 PM       5
# 8:55:36 PM       5
# 8:57:56 PM       5
# 9:35:47 PM       5
# 9:37:27 PM       5
# 8:57:46 PM       5
# 8:58:26 PM       5
# 9:40:27 PM       5
# 9:31:27 PM       5
# 8:55:46 PM       5
# 9:05:56 PM       5
# 9:38:27 PM       5
# 8:55:26 PM       5
# 8:58:56 PM       5
# 9:30:17 PM       4
# 8:05:11 PM       4
# 8:51:36 PM       4
# 8:31:11 PM       4
# 10:01:35 PM      4
# 9:36:57 PM       4
# 8:38:46 PM       4
# 10:02:05 PM      4
# 9:25:56 PM       4
# 8:53:45 PM       4
# 8:38:05 PM       4
# 8:38:06 PM       4
# 8:26:26 PM       4
# 9:07:25 PM       4
# 9:07:36 PM       4
#               ...
# 9:40:46 PM       1
# 11:35:08 PM      1
# 9:57:51 PM       1
# 10:19:13 PM      1
# 9:40:06 PM       1
# 9:05:12 PM       1
# 8:44:51 PM       1
# 8:29:53 PM       1
# 9:43:14 PM       1
# 11:49:31 PM      1
# 10:58:06 PM      1
# 11:15:01 PM      1
# 8:49:48 PM       1
# 8:52:59 PM       1
# 11:56:31 PM      1
# ...

# %%
sns.distplot(data.Date.value_counts(), bins=10)
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.xticks(rotation=90)

plt.show()

# %%
data['coordinates']=data.Latitude.astype(str)+', '+data.Longitude.astype(str)

# %%
data['address'] = np.nan
data.head()
# Out:
#          Date        Time   Latitude  Longitude           full_date  \
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163 2011-08-29 18:56:58
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163 2011-08-29 18:57:08
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157 2011-08-29 18:57:18
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158 2011-08-29 18:57:28
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858 2011-08-29 18:57:38
#
#                      coordinates  address
# 0  42.3916233333, -88.0891633333      NaN
# 1  42.3913483333, -88.0891633333      NaN
# 2  42.3910216667, -88.0891566667      NaN
# 3  42.3906366667, -88.0891583333      NaN
# 4       42.39041, -88.0888583333      NaN

# %%
data.coordinates[100]
# Out:
# '41.9793516667, -87.7877533333'

# %%
data.Latitude.loc[0]
# Out:
# 42.3916233333333

# %%
for i in range(1, len(data.coordinates)):
    try:
        loc = geolocator.reverse(data.coordinates[i])
        data.address[i] = loc.address
    except:
        data.address[i]= np.nan
data.head()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          Date        Time   Latitude  Longitude           full_date  \
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163 2011-08-29 18:56:58
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163 2011-08-29 18:57:08
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157 2011-08-29 18:57:18
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158 2011-08-29 18:57:28
# ...

# %%
data.address[0] = data.address[1]
data.head()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          Date        Time   Latitude  Longitude           full_date  \
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163 2011-08-29 18:56:58
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163 2011-08-29 18:57:08
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157 2011-08-29 18:57:18
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158 2011-08-29 18:57:28
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858 2011-08-29 18:57:38
#
#                      coordinates  \
# 0  42.3916233333, -88.0891633333
# 1  42.3913483333, -88.0891633333
# 2  42.3910216667, -88.0891566667
# 3  42.3906366667, -88.0891583333
# 4       42.39041, -88.0888583333
#
#                                              address
# ...

# %%
eda(data)
# Out:
# missing values
# Date               0
# Time             584
# Latitude           0
# Longitude          0
# full_date        584
# coordinates        0
# address        13674
# dtype: int64
# dataframe index
# RangeIndex(start=0, stop=14835, step=1)
# dataframe types
# Date                   object
# Time                   object
# Latitude              float64
# Longitude             float64
# full_date      datetime64[ns]
# coordinates            object
# address                object
# dtype: object
# dataframe shape
# (14835, 7)
# dataframe describe
#            Latitude     Longitude
# count  14835.000000  14835.000000
# mean      41.904828    -87.736690
# std        0.104381      0.067292
# min       41.713925    -88.096468
# 25%       41.785001    -87.794225
# 50%       41.940075    -87.727853
# 75%       41.980978    -87.694108
# max       42.395983    -87.586727
# dataframe duplicates
# 540
# Date
# 10
# Time
# 8583
# Latitude
# 12887
# Longitude
# 13007
# full_date
# ...

# %%
for i in range(1, len(data.coordinates)):
    if data.address[i] != None:
        pass
    else:
        try:
            loc = geolocator.reverse(data.coordinates[i])
            data.address[i] = loc.address
        except:
            data.address[i]= np.nan    
data.head()
# Out:
#          Date        Time   Latitude  Longitude           full_date  \
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163 2011-08-29 18:56:58
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163 2011-08-29 18:57:08
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157 2011-08-29 18:57:18
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158 2011-08-29 18:57:28
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858 2011-08-29 18:57:38
#
#                      coordinates  \
# 0  42.3916233333, -88.0891633333
# 1  42.3913483333, -88.0891633333
# 2  42.3910216667, -88.0891566667
# 3  42.3906366667, -88.0891583333
# 4       42.39041, -88.0888583333
#
#                                              address
# 0  Ridgewood Lane, Lake Villa, Lake County, Illin...
# 1  Ridgewood Lane, Lake Villa, Lake County, Illin...
# 2  Ridgewood Lane, Lake Villa, Lake County, Illin...
# 3  Ridgewood Lane, Lake Villa, Lake County, Illin...
# 4  Ridgewood Lane, Lake Villa, Lake County, Illin...

# %%
data.to_csv('/Users/andresgonzalez/Desktop/GA/curriculum/West-Nile-Virus-Prediction/newspray.csv')
