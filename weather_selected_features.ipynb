# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# import the EDA functions I've built in a Python script
import eda

# %%
# # increase the number of characters shown for each column
pd.set_option('display.max_colwidth', 100)
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # EDA

# %% [markdown]
# ## weather

# %%
weather = pd.read_csv('assets/weather.csv', 
                      parse_dates=['Date'], infer_datetime_format=True, 
                      na_values=['M', '-'])  # M = Missing Data

weather['Station'] = weather['Station'].astype('category')
    
weather.shape
# Out:
# (2944, 22)

# %%
weather.isnull().sum()
# Out:
# Station           0
# Date              0
# Tmax              0
# Tmin              0
# Tavg             11
# Depart         1472
# DewPoint          0
# WetBulb           4
# Heat             11
# Cool             11
# Sunrise        1472
# Sunset         1472
# CodeSum           0
# Depth          1472
# Water1         2944
# SnowFall       1472
# PrecipTotal       2
# StnPressure       4
# SeaLevel          9
# ResultSpeed       0
# ResultDir         0
# AvgSpeed          3
# dtype: int64

# %%
# Water1 does not have any useful info -- drop!
weather.drop('Water1', axis=1, inplace=True)

eda.eda(weather)
# Out:
# Head of the dataframe:
#
#   Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  Cool  \
# 0       1 2007-05-01    83    50  67.0    14.0        51     56.0   0.0   2.0
# 1       2 2007-05-01    84    52  68.0     NaN        51     57.0   0.0   3.0
# 2       1 2007-05-02    59    42  51.0    -3.0        42     47.0  14.0   0.0
# 3       2 2007-05-02    60    43  52.0     NaN        42     47.0  13.0   0.0
# 4       1 2007-05-03    66    46  56.0     2.0        40     48.0   9.0   0.0
#
#    Sunrise  Sunset CodeSum  Depth SnowFall PrecipTotal  StnPressure  SeaLevel  \
# 0    448.0  1849.0            0.0      0.0        0.00        29.10     29.82
# 1      NaN     NaN            NaN      NaN        0.00        29.18     29.82
# 2    447.0  1850.0      BR    0.0      0.0        0.00        29.38     30.09
# 3      NaN     NaN   BR HZ    NaN      NaN        0.00        29.44     30.08
# 4    446.0  1851.0            0.0      0.0        0.00        29.39     30.12
#
#    ResultSpeed  ResultDir  AvgSpeed
# 0          1.7         27       9.2
# 1          2.7         25       9.6
# 2         13.0          4      13.4
# 3         13.3          2      13.4
# 4         11.7          7      11.9
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 21 columns):
# Station        2944 non-null category
# Date           2944 non-null datetime64[ns]
# Tmax           2944 non-null int64
# Tmin           2944 non-null int64
# Tavg           2933 non-null float64
# Depart         1472 non-null float64
# DewPoint       2944 non-null int64
# WetBulb        2940 non-null float64
# Heat           2933 non-null float64
# Cool           2933 non-null float64
# Sunrise        1472 non-null float64
# Sunset         1472 non-null float64
# CodeSum        2944 non-null object
# Depth          1472 non-null float64
# SnowFall       1472 non-null object
# PrecipTotal    2942 non-null object
# StnPressure    2940 non-null float64
# SeaLevel       2935 non-null float64
# ResultSpeed    2944 non-null float64
# ResultDir      2944 non-null int64
# AvgSpeed       2941 non-null float64
# dtypes: category(1), datetime64[ns](1), float64(12), int64(4), object(3)
# memory usage: 463.0+ KB
#
#
#               Tmax         Tmin         Tavg       Depart     DewPoint  \
# count  2944.000000  2944.000000  2933.000000  1472.000000  2944.000000
# mean     76.166101    57.810462    67.240027     1.954484    53.457880
# std      11.461970    10.381939    10.545442     6.841110    10.675181
# min      41.000000    29.000000    36.000000   -17.000000    22.000000
# 25%      69.000000    50.000000    60.000000    -3.000000    46.000000
# 50%      78.000000    59.000000    69.000000     2.000000    54.000000
# 75%      85.000000    66.000000    75.000000     7.000000    62.000000
# max     104.000000    83.000000    94.000000    23.000000    75.000000
#
#            WetBulb         Heat         Cool      Sunrise       Sunset  \
# count  2940.000000  2933.000000  2933.000000  1472.000000  1472.000000
# mean     59.310884     3.407092     5.647119   480.646739  1847.347826
# std       9.286742     5.953203     6.105087    65.344729    87.050615
# min      32.000000     0.000000     0.000000   416.000000  1647.000000
# 25%      53.000000     0.000000     0.000000   424.750000  1792.250000
# 50%      61.000000     0.000000     4.000000   446.500000  1859.500000
# 75%      67.000000     5.000000    10.000000   531.250000  1922.250000
# max      78.000000    29.000000    29.000000   623.000000  1931.000000
#
#         Depth  StnPressure     SeaLevel  ResultSpeed    ResultDir     AvgSpeed
# count  1472.0  2940.000000  2935.000000  2944.000000  2944.000000  2941.000000
# mean      0.0    29.284429    29.968129     6.960666    17.494905     8.580449
# std       0.0     0.158543     0.158597     3.587527    10.063609     3.147300
# min       0.0    28.550000    29.230000     0.100000     1.000000     1.700000
# 25%       0.0    29.190000    29.870000     4.300000     7.000000     6.300000
# 50%       0.0    29.280000    29.970000     6.400000    19.000000     8.100000
# 75%       0.0    29.390000    30.060000     9.200000    25.000000    10.400000
# max       0.0    29.860000    30.530000    24.100000    36.000000    26.300000
#
#
#                        Date
# count                  2944
# unique                 1472
# top     2014-08-27 00:00:00
# freq                      2
# first   2007-05-01 00:00:00
# last    2014-10-31 00:00:00
#
#
#         Station CodeSum SnowFall PrecipTotal
# count      2944    2944     1472        2942
# unique        2      98        3         167
# top           2              0.0        0.00
# freq       1472    1609     1459        1577
#
#
# Number of duplicated rows: 0

# %%
# drop redundant or unnecessary variables
weather.drop(['Tmax', 'Tmin', 'Depart', 'WetBulb', 'Heat', 'Cool', # these are all measurements of temp.
              'CodeSum', 
              'Depth',  # Depth has no variation at all
              'StnPressure', 'SeaLevel',  # measurements of pressure -- little variations
              'ResultSpeed'],  # measurement of wind (aggregated in AvgSpeed)
             axis=1, inplace=True)

# %%
eda.category_counts(weather)
# Out:
# 2    1472
# 1    1472
# Name: Station, dtype: int64
#
#
# 0.0    1459
#   T      12
# 0.1       1
# Name: SnowFall, dtype: int64
#
#
# 0.00    1577
#   T      318
# 0.01     127
# 0.02      63
# 0.03      46
# 0.04      36
# 0.05      32
# 0.12      28
# 0.08      28
# 0.06      27
# 0.07      23
# 0.16      21
# 0.09      21
# 0.11      20
# 0.14      20
# 0.17      17
# 0.28      15
# 0.13      14
# 0.19      14
# 0.18      14
# 0.20      13
# 0.15      13
# 0.23      11
# 0.25      11
# 0.26      11
# 0.10      10
# 0.24      10
# 0.39       9
# 0.40       9
# 0.21       9
#         ...
# 2.09       1
# 1.21       1
# 3.66       1
# 2.24       1
# 1.26       1
# 1.90       1
# 6.64       1
# 1.46       1
# 3.31       1
# 2.90       1
# 1.22       1
# 0.90       1
# 1.58       1
# 3.17       1
# 3.07       1
# 1.24       1
# 0.62       1
# 1.35       1
# 1.25       1
# 1.19       1
# 1.09       1
# 1.14       1
# 1.49       1
# 0.98       1
# 2.60       1
# 1.34       1
# 0.76       1
# 2.79       1
# 1.73       1
# 3.64       1
# Name: PrecipTotal, Length: 167, dtype: int64

# %%
weather.SnowFall.unique()
# Note the whitespace with T (gah!)
# Out:
# array(['0.0', nan, '  T', '0.1'], dtype=object)

# %%
weather.PrecipTotal.unique()
# Note the whitespace with T
# Out:
# array(['0.00', '  T', '0.13', '0.02', '0.38', '0.60', '0.14', '0.07',
#        '0.11', '0.09', '1.01', '0.28', '0.04', '0.08', '0.01', '0.53',
#        '0.19', '0.21', '0.32', '0.39', '0.31', '0.42', '0.27', '0.16',
#        '0.58', '0.93', '0.05', '0.34', '0.15', '0.35', nan, '0.40', '0.66',
#        '0.30', '0.24', '0.43', '1.55', '0.92', '0.89', '0.17', '0.03',
#        '1.43', '0.97', '0.26', '1.31', '0.06', '0.46', '0.29', '0.23',
#        '0.41', '0.45', '0.83', '1.33', '0.91', '0.48', '0.37', '0.88',
#        '2.35', '1.96', '0.20', '0.25', '0.18', '0.67', '0.36', '0.33',
#        '1.28', '0.74', '0.76', '0.71', '0.95', '1.46', '0.12', '0.52',
#        '0.64', '0.22', '1.24', '0.72', '0.73', '0.65', '1.61', '1.22',
#        '0.50', '1.05', '2.43', '0.59', '2.90', '2.68', '1.23', '0.62',
#        '6.64', '3.07', '1.44', '1.75', '0.82', '0.80', '0.86', '0.63',
#        '0.55', '1.03', '0.70', '1.73', '1.38', '0.44', '1.14', '1.07',
#        '3.97', '0.87', '0.78', '1.12', '0.68', '0.10', '0.61', '0.54',
#        '1.19', '0.75', '0.84', '1.29', '0.81', '1.15', '1.49', '1.57',
#        '1.02', '1.30', '0.51', '0.85', '0.79', '0.77', '2.79', '3.15',
#        '3.64', '4.73', '1.60', '0.57', '2.24', '1.90', '1.06', '1.88',
#        '0.69', '2.17', '6.86', '0.49', '1.11', '1.21', '0.90', '1.34',
#        '0.47', '0.56', '3.66', '1.09', '1.25', '1.35', '2.20', '1.48',
#        '0.96', '1.16', '1.04', '2.03', '2.09', '1.26', '2.60', '2.06',
#        '3.31', '2.76', '1.82', '0.98', '1.58', '3.17', '1.18'], dtype=object)

# %%
# T in SnowFall and PrecipTotal means Trace
# arbitrarily convert T to 0.001 in SnowFall/PrecipTotal so that dtype can be changed to float
weather.SnowFall = weather.SnowFall.apply(lambda x: 0.001 if x=='  T' else x).astype(np.float)
weather.PrecipTotal = weather.PrecipTotal.apply(lambda x: 0.001 if x=='  T' else x).astype(np.float)

# %%
# convert Sunrise and Sunset to the number of hours passed since midnight (00:00 am)
def convert_timestamp(timestamp):
    if pd.isnull(timestamp):
        return timestamp
    else:
        hour = np.floor(timestamp/100)
        min_to_hour = (timestamp - hour * 100) / 60
        return hour + min_to_hour

weather.Sunrise = weather.Sunrise.apply(convert_timestamp)
weather.Sunset = weather.Sunset.apply(convert_timestamp)
weather[['Sunrise', 'Sunset']].head()
# Out:
#     Sunrise     Sunset
# 0  4.800000  18.816667
# 1       NaN        NaN
# 2  4.783333  18.833333
# 3       NaN        NaN
# 4  4.766667  18.850000

# %%
# average station 1 and station 2 data from the same day
df = weather.groupby('Date').mean()
eda.eda(df)
# Out:
# Head of the dataframe:
#
#             Tavg  DewPoint   Sunrise     Sunset  SnowFall  PrecipTotal  \
# Date
# 2007-05-01  67.5      51.0  4.800000  18.816667       0.0       0.0000
# 2007-05-02  51.5      42.0  4.783333  18.833333       0.0       0.0000
# 2007-05-03  57.0      40.0  4.766667  18.850000       0.0       0.0000
# 2007-05-04  58.0      41.5  4.733333  18.866667       0.0       0.0005
# 2007-05-05  60.0      38.5  4.716667  18.883333       0.0       0.0010
#
#             ResultDir  AvgSpeed
# Date
# 2007-05-01       26.0      9.40
# 2007-05-02        3.0     13.40
# 2007-05-03        6.5     12.55
# 2007-05-04        7.5     10.60
# 2007-05-05        7.0     11.75
#
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1472 entries, 2007-05-01 to 2014-10-31
# Data columns (total 8 columns):
# Tavg           1472 non-null float64
# DewPoint       1472 non-null float64
# Sunrise        1472 non-null float64
# Sunset         1472 non-null float64
# SnowFall       1472 non-null float64
# PrecipTotal    1472 non-null float64
# ResultDir      1472 non-null float64
# AvgSpeed       1472 non-null float64
# dtypes: float64(8)
# memory usage: 103.5 KB
#
#
#               Tavg     DewPoint      Sunrise       Sunset     SnowFall  \
# count  1472.000000  1472.000000  1472.000000  1472.000000  1472.000000
# mean     67.223505    53.457880     4.992663    18.662319     0.000076
# std      10.513691    10.649199     0.651882     0.843714     0.002608
# min      36.000000    22.500000     4.266667    16.783333     0.000000
# 25%      60.500000    46.000000     4.412500    18.037500     0.000000
# 50%      69.000000    54.500000     4.775000    18.991667     0.000000
# 75%      75.500000    61.500000     5.520833    19.370833     0.000000
# max      93.500000    74.500000     6.383333    19.516667     0.100000
#
#        PrecipTotal    ResultDir     AvgSpeed
# count  1472.000000  1472.000000  1472.000000
# mean      0.131348    17.494905     8.579076
# std       0.358490     9.606755     3.107534
# min       0.000000     1.000000     2.000000
# 25%       0.000000     8.000000     6.300000
# 50%       0.000500    19.000000     8.050000
# 75%       0.080000    24.500000    10.362500
# max       4.855000    36.000000    23.850000
#
#
# Number of duplicated rows: 0

# %%
sns.pairplot(df);

# %% [markdown]
# #### `Tavg` and `DewPoint` are highly correlated!
#
# ##### According to [this website](http://andrew.rsmas.miami.edu/bmcnoldy/Humidity.html), a way to calculate Relative Humidity from temperature and dew point:
# RH = 100*(EXP((17.625*TD)/(243.04+TD))/EXP((17.625*T)/(243.04+T)))
# TD and T in Celcius
#
# ##### [Wikipedia](https://en.wikipedia.org/wiki/Dew_point) gives a simpler approximation:
# RH = 100 - (Tavg - DewPoint) * (25/9)
# Tavg and DewPoint in Fahrenheit

# %%
# approximate Relative Humidity from Temperature and Dew Point
df['RH'] = 100 - (df.Tavg - df.DewPoint) * (25/9)

df.drop('DewPoint', axis=1, inplace=True)
sns.pairplot(df);

# %%
fig, axes = plt.subplots(nrows=len(df.columns), figsize=(12, 25))
for index, col in enumerate(df.columns):
    ax = axes[index]
    ax.plot(df[col]);
    ax.set_ylabel(col);

# %% [markdown]
# #### Note: May want to drop `SnowFall` in the future.

# %%
df.to_csv('assets/weather_selected_features.csv')
